# %% [markdown]
# # P13-1 실습 과제
# ##Mini-batch size & Learning Rate 튜닝

# %%
# mlp for the blobs problem with minibatch gradient descent with varied batch size
# 아래의 코드에서 다음 두 개의 파라미터를 조합하여 최고의 모델링 성능을 내고 그 결과를 print()로 출력하십시오.
# 튜닝할 파라미터 : batch_size & lr (각각 3가지의 옵션이 있으므로 두 파라미터를 조합할 수 있는 경우의 수는 모두 9가지)
# 모델의 성능 평가 기준은 다음의 우선순위에 따라 결정하시오. 
# 1. Validation Loss가 최소, 2. Accuracy는 최고값에 가까울 것
# 9번의 실험 후 최적이라고 생각되는 파라미터 값을 코드에 지정하고 셀을 다시 run하여 최종 결과를 출력하시오.
from sklearn.datasets import make_blobs
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from keras.utils.np_utils import to_categorical
from matplotlib import pyplot

# prepare train and test dataset
def prepare_data():
	# generate 2d classification dataset
	X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)
	# one hot encode output variable
	y = to_categorical(y)
	# split into train and test
	n_train = 500
	trainX, testX = X[:n_train, :], X[n_train:, :]
	trainy, testy = y[:n_train], y[n_train:]
	return trainX, trainy, testX, testy

# fit a model and plot learning curve
def fit_model(trainX, trainy, testX, testy, n_batch):
	
  # define model
	model = Sequential()
	model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(3, activation='softmax'))
	
  # lr의 값을  0.1, 0.01, 0.001 중에서 선택하여 이곳에 지정
	opt = SGD(lr=0.01, momentum=0.9) 
	model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
	# fit model
	history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=150, verbose=2, batch_size=n_batch)
	print('accuracy = ', format(history.history['accuracy'][149],".3f"), ' ', 'validation loss = ', format(history.history['val_loss'][149],".3f"))
  # plot learning curves
	pyplot.plot(history.history['accuracy'], label='train')
	pyplot.plot(history.history['val_loss'], label='test')
	pyplot.title('batch='+str(n_batch), pad=-40)



# prepare dataset
trainX, trainy, testX, testy = prepare_data()

# batch_size의 값을   16, 32, 64 중에서 선택하여 이곳에 지정
batch_size = 64

fit_model(trainX, trainy, testX, testy, batch_size)
# show learning curves
pyplot.show()

# 결과를 메모장에 적어놓고 lr과 batch_size를 바꿔가며 최적의 파라미터를 찾아가시오.
# 최적의 lr과 batch_size를 선택하여 위의 코드에 적고 Run한 결과룰 출력하여 제출하시오.
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/150
# 8/8 - 1s - loss: 1.5673 - accuracy: 0.4860 - val_loss: 0.6992 - val_accuracy: 0.6880
# Epoch 2/150
# 8/8 - 0s - loss: 0.9342 - accuracy: 0.6140 - val_loss: 0.9060 - val_accuracy: 0.6180
# Epoch 3/150
# 8/8 - 0s - loss: 0.7845 - accuracy: 0.6300 - val_loss: 0.7064 - val_accuracy: 0.6800
# Epoch 4/150
# 8/8 - 0s - loss: 0.8603 - accuracy: 0.6200 - val_loss: 0.6477 - val_accuracy: 0.6900
# Epoch 5/150
# 8/8 - 0s - loss: 0.7421 - accuracy: 0.6560 - val_loss: 0.5943 - val_accuracy: 0.7360
# Epoch 6/150
# 8/8 - 0s - loss: 0.6421 - accuracy: 0.7020 - val_loss: 0.5853 - val_accuracy: 0.7160
# Epoch 7/150
# 8/8 - 0s - loss: 0.6144 - accuracy: 0.7000 - val_loss: 0.5798 - val_accuracy: 0.7380
# Epoch 8/150
# 8/8 - 0s - loss: 0.6230 - accuracy: 0.7220 - val_loss: 0.6017 - val_accuracy: 0.7140
# Epoch 9/150
# 8/8 - 0s - loss: 0.6034 - accuracy: 0.7260 - val_loss: 0.6376 - val_accuracy: 0.7480
# Epoch 10/150
# 8/8 - 0s - loss: 0.6164 - accuracy: 0.7380 - val_loss: 0.7414 - val_accuracy: 0.5860
# Epoch 11/150
# 8/8 - 0s - loss: 0.7328 - accuracy: 0.6340 - val_loss: 0.5842 - val_accuracy: 0.7460
# Epoch 12/150
# 8/8 - 0s - loss: 0.5942 - accuracy: 0.7400 - val_loss: 0.5439 - val_accuracy: 0.7920
# Epoch 13/150
# 8/8 - 0s - loss: 0.5402 - accuracy: 0.7780 - val_loss: 0.5584 - val_accuracy: 0.7880
# Epoch 14/150
# 8/8 - 0s - loss: 0.5529 - accuracy: 0.7500 - val_loss: 0.5501 - val_accuracy: 0.7520
# Epoch 15/150
# 8/8 - 0s - loss: 0.6648 - accuracy: 0.7200 - val_loss: 0.7315 - val_accuracy: 0.5820
# Epoch 16/150
# 8/8 - 0s - loss: 0.5904 - accuracy: 0.7400 - val_loss: 0.4844 - val_accuracy: 0.8060
# Epoch 17/150
# 8/8 - 0s - loss: 0.5261 - accuracy: 0.7660 - val_loss: 0.4870 - val_accuracy: 0.8200
# Epoch 18/150
# 8/8 - 0s - loss: 0.5303 - accuracy: 0.7660 - val_loss: 0.6440 - val_accuracy: 0.7380
# Epoch 19/150
# 8/8 - 0s - loss: 0.5343 - accuracy: 0.7700 - val_loss: 0.4788 - val_accuracy: 0.8200
# Epoch 20/150
# 8/8 - 0s - loss: 0.4903 - accuracy: 0.7820 - val_loss: 0.4613 - val_accuracy: 0.8200
# Epoch 21/150
# 8/8 - 0s - loss: 0.4937 - accuracy: 0.7740 - val_loss: 1.0043 - val_accuracy: 0.5280
# Epoch 22/150
# 8/8 - 0s - loss: 0.7395 - accuracy: 0.6700 - val_loss: 0.5812 - val_accuracy: 0.7520
# Epoch 23/150
# 8/8 - 0s - loss: 0.5308 - accuracy: 0.7720 - val_loss: 0.4525 - val_accuracy: 0.8240
# Epoch 24/150
# 8/8 - 0s - loss: 0.4874 - accuracy: 0.7960 - val_loss: 0.4770 - val_accuracy: 0.8260
# Epoch 25/150
# 8/8 - 0s - loss: 0.4877 - accuracy: 0.7680 - val_loss: 0.4460 - val_accuracy: 0.8160
# Epoch 26/150
# 8/8 - 0s - loss: 0.4737 - accuracy: 0.7900 - val_loss: 0.4910 - val_accuracy: 0.8160
# Epoch 27/150
# 8/8 - 0s - loss: 0.4658 - accuracy: 0.8000 - val_loss: 0.4329 - val_accuracy: 0.8300
# Epoch 28/150
# 8/8 - 0s - loss: 0.4576 - accuracy: 0.8140 - val_loss: 0.4363 - val_accuracy: 0.8320
# Epoch 29/150
# 8/8 - 0s - loss: 0.4494 - accuracy: 0.8160 - val_loss: 0.4731 - val_accuracy: 0.8140
# Epoch 30/150
# 8/8 - 0s - loss: 0.4711 - accuracy: 0.7860 - val_loss: 0.4345 - val_accuracy: 0.8320
# Epoch 31/150
# 8/8 - 0s - loss: 0.4453 - accuracy: 0.8140 - val_loss: 0.4221 - val_accuracy: 0.8320
# Epoch 32/150
# 8/8 - 0s - loss: 0.4779 - accuracy: 0.7720 - val_loss: 0.4514 - val_accuracy: 0.8140
# Epoch 33/150
# 8/8 - 0s - loss: 0.4633 - accuracy: 0.7980 - val_loss: 0.4654 - val_accuracy: 0.8180
# Epoch 34/150
# 8/8 - 0s - loss: 0.4486 - accuracy: 0.8180 - val_loss: 0.4234 - val_accuracy: 0.8320
# Epoch 35/150
# 8/8 - 0s - loss: 0.4430 - accuracy: 0.8060 - val_loss: 0.5005 - val_accuracy: 0.7900
# Epoch 36/150
# 8/8 - 0s - loss: 0.4419 - accuracy: 0.8180 - val_loss: 0.5104 - val_accuracy: 0.7820
# Epoch 37/150
# 8/8 - 0s - loss: 0.4474 - accuracy: 0.7980 - val_loss: 0.4412 - val_accuracy: 0.8220
# Epoch 38/150
# 8/8 - 0s - loss: 0.4333 - accuracy: 0.8140 - val_loss: 0.4626 - val_accuracy: 0.8080
# Epoch 39/150
# 8/8 - 0s - loss: 0.4969 - accuracy: 0.7900 - val_loss: 0.4816 - val_accuracy: 0.8000
# Epoch 40/150
# 8/8 - 0s - loss: 0.4729 - accuracy: 0.7900 - val_loss: 0.4161 - val_accuracy: 0.8320
# Epoch 41/150
# 8/8 - 0s - loss: 0.4838 - accuracy: 0.7860 - val_loss: 0.5470 - val_accuracy: 0.7460
# Epoch 42/150
# 8/8 - 0s - loss: 0.5096 - accuracy: 0.7720 - val_loss: 0.6194 - val_accuracy: 0.7240
# Epoch 43/150
# 8/8 - 0s - loss: 0.5526 - accuracy: 0.7680 - val_loss: 0.4139 - val_accuracy: 0.8320
# Epoch 44/150
# 8/8 - 0s - loss: 0.4528 - accuracy: 0.8120 - val_loss: 0.4465 - val_accuracy: 0.8100
# Epoch 45/150
# 8/8 - 0s - loss: 0.4487 - accuracy: 0.7980 - val_loss: 0.4354 - val_accuracy: 0.8180
# Epoch 46/150
# 8/8 - 0s - loss: 0.4932 - accuracy: 0.8040 - val_loss: 0.4370 - val_accuracy: 0.8080
# Epoch 47/150
# 8/8 - 0s - loss: 0.4509 - accuracy: 0.8140 - val_loss: 0.4039 - val_accuracy: 0.8260
# Epoch 48/150
# 8/8 - 0s - loss: 0.4399 - accuracy: 0.8200 - val_loss: 0.4093 - val_accuracy: 0.8320
# Epoch 49/150
# 8/8 - 0s - loss: 0.4407 - accuracy: 0.8100 - val_loss: 0.4157 - val_accuracy: 0.8240
# Epoch 50/150
# 8/8 - 0s - loss: 0.4311 - accuracy: 0.8060 - val_loss: 0.4330 - val_accuracy: 0.8220
# Epoch 51/150
# 8/8 - 0s - loss: 0.4183 - accuracy: 0.8120 - val_loss: 0.4218 - val_accuracy: 0.8200
# Epoch 52/150
# 8/8 - 0s - loss: 0.4331 - accuracy: 0.8200 - val_loss: 0.3997 - val_accuracy: 0.8380
# Epoch 53/150
# 8/8 - 0s - loss: 0.4129 - accuracy: 0.8220 - val_loss: 0.4058 - val_accuracy: 0.8300
# Epoch 54/150
# 8/8 - 0s - loss: 0.4165 - accuracy: 0.8280 - val_loss: 0.3985 - val_accuracy: 0.8380
# Epoch 55/150
# 8/8 - 0s - loss: 0.4234 - accuracy: 0.8220 - val_loss: 0.4058 - val_accuracy: 0.8340
# Epoch 56/150
# 8/8 - 0s - loss: 0.4507 - accuracy: 0.8160 - val_loss: 0.3994 - val_accuracy: 0.8300
# Epoch 57/150
# 8/8 - 0s - loss: 0.4254 - accuracy: 0.8320 - val_loss: 0.4268 - val_accuracy: 0.8120
# Epoch 58/150
# 8/8 - 0s - loss: 0.4368 - accuracy: 0.8120 - val_loss: 0.4230 - val_accuracy: 0.8220
# Epoch 59/150
# 8/8 - 0s - loss: 0.4422 - accuracy: 0.8160 - val_loss: 0.4179 - val_accuracy: 0.8220
# Epoch 60/150
# 8/8 - 0s - loss: 0.4605 - accuracy: 0.8000 - val_loss: 0.4078 - val_accuracy: 0.8240
# Epoch 61/150
# 8/8 - 0s - loss: 0.4596 - accuracy: 0.8140 - val_loss: 0.4172 - val_accuracy: 0.8240
# Epoch 62/150
# 8/8 - 0s - loss: 0.4205 - accuracy: 0.8140 - val_loss: 0.3985 - val_accuracy: 0.8380
# Epoch 63/150
# 8/8 - 0s - loss: 0.4110 - accuracy: 0.8380 - val_loss: 0.4208 - val_accuracy: 0.8280
# Epoch 64/150
# 8/8 - 0s - loss: 0.4369 - accuracy: 0.7940 - val_loss: 0.4051 - val_accuracy: 0.8300
# Epoch 65/150
# 8/8 - 0s - loss: 0.4498 - accuracy: 0.8140 - val_loss: 0.4112 - val_accuracy: 0.8240
# Epoch 66/150
# 8/8 - 0s - loss: 0.4643 - accuracy: 0.8100 - val_loss: 0.3999 - val_accuracy: 0.8320
# Epoch 67/150
# 8/8 - 0s - loss: 0.4374 - accuracy: 0.8220 - val_loss: 0.4117 - val_accuracy: 0.8240
# Epoch 68/150
# 8/8 - 0s - loss: 0.4295 - accuracy: 0.8020 - val_loss: 0.3981 - val_accuracy: 0.8360
# Epoch 69/150
# 8/8 - 0s - loss: 0.4131 - accuracy: 0.8380 - val_loss: 0.3993 - val_accuracy: 0.8300
# Epoch 70/150
# 8/8 - 0s - loss: 0.4023 - accuracy: 0.8360 - val_loss: 0.3991 - val_accuracy: 0.8220
# Epoch 71/150
# 8/8 - 0s - loss: 0.3988 - accuracy: 0.8240 - val_loss: 0.4752 - val_accuracy: 0.7960
# Epoch 72/150
# 8/8 - 0s - loss: 0.4261 - accuracy: 0.8180 - val_loss: 0.4238 - val_accuracy: 0.8280
# Epoch 73/150
# 8/8 - 0s - loss: 0.4229 - accuracy: 0.8120 - val_loss: 0.3984 - val_accuracy: 0.8300
# Epoch 74/150
# 8/8 - 0s - loss: 0.4209 - accuracy: 0.8180 - val_loss: 0.4037 - val_accuracy: 0.8360
# Epoch 75/150
# 8/8 - 0s - loss: 0.4097 - accuracy: 0.8120 - val_loss: 0.3956 - val_accuracy: 0.8340
# Epoch 76/150
# 8/8 - 0s - loss: 0.4105 - accuracy: 0.8320 - val_loss: 0.4249 - val_accuracy: 0.8240
# Epoch 77/150
# 8/8 - 0s - loss: 0.4516 - accuracy: 0.8160 - val_loss: 0.4370 - val_accuracy: 0.8100
# Epoch 78/150
# 8/8 - 0s - loss: 0.5082 - accuracy: 0.7760 - val_loss: 0.6136 - val_accuracy: 0.7480
# Epoch 79/150
# 8/8 - 0s - loss: 0.6027 - accuracy: 0.7680 - val_loss: 0.5378 - val_accuracy: 0.7720
# Epoch 80/150
# 8/8 - 0s - loss: 0.5252 - accuracy: 0.7900 - val_loss: 0.3970 - val_accuracy: 0.8360
# Epoch 81/150
# 8/8 - 0s - loss: 0.4167 - accuracy: 0.8140 - val_loss: 0.4037 - val_accuracy: 0.8240
# Epoch 82/150
# 8/8 - 0s - loss: 0.4172 - accuracy: 0.8160 - val_loss: 0.4041 - val_accuracy: 0.8300
# Epoch 83/150
# 8/8 - 0s - loss: 0.4184 - accuracy: 0.8100 - val_loss: 0.4162 - val_accuracy: 0.8220
# Epoch 84/150
# 8/8 - 0s - loss: 0.4233 - accuracy: 0.8180 - val_loss: 0.4608 - val_accuracy: 0.8060
# Epoch 85/150
# 8/8 - 0s - loss: 0.4267 - accuracy: 0.8180 - val_loss: 0.4568 - val_accuracy: 0.8160
# Epoch 86/150
# 8/8 - 0s - loss: 0.4122 - accuracy: 0.8180 - val_loss: 0.4174 - val_accuracy: 0.8140
# Epoch 87/150
# 8/8 - 0s - loss: 0.3990 - accuracy: 0.8340 - val_loss: 0.4067 - val_accuracy: 0.8260
# Epoch 88/150
# 8/8 - 0s - loss: 0.3926 - accuracy: 0.8300 - val_loss: 0.4152 - val_accuracy: 0.8240
# Epoch 89/150
# 8/8 - 0s - loss: 0.4039 - accuracy: 0.8200 - val_loss: 0.3970 - val_accuracy: 0.8240
# Epoch 90/150
# 8/8 - 0s - loss: 0.4012 - accuracy: 0.8260 - val_loss: 0.4170 - val_accuracy: 0.8200
# Epoch 91/150
# 8/8 - 0s - loss: 0.4202 - accuracy: 0.8220 - val_loss: 0.3967 - val_accuracy: 0.8300
# Epoch 92/150
# 8/8 - 0s - loss: 0.4373 - accuracy: 0.8080 - val_loss: 0.4032 - val_accuracy: 0.8280
# Epoch 93/150
# 8/8 - 0s - loss: 0.4305 - accuracy: 0.8260 - val_loss: 0.4541 - val_accuracy: 0.8000
# Epoch 94/150
# 8/8 - 0s - loss: 0.4261 - accuracy: 0.8160 - val_loss: 0.4070 - val_accuracy: 0.8240
# Epoch 95/150
# 8/8 - 0s - loss: 0.4403 - accuracy: 0.8100 - val_loss: 0.4029 - val_accuracy: 0.8200
# Epoch 96/150
# 8/8 - 0s - loss: 0.4725 - accuracy: 0.7920 - val_loss: 0.4221 - val_accuracy: 0.8280
# Epoch 97/150
# 8/8 - 0s - loss: 0.4379 - accuracy: 0.7980 - val_loss: 0.4563 - val_accuracy: 0.8020
# Epoch 98/150
# 8/8 - 0s - loss: 0.3934 - accuracy: 0.8300 - val_loss: 0.3966 - val_accuracy: 0.8240
# Epoch 99/150
# 8/8 - 0s - loss: 0.3960 - accuracy: 0.8340 - val_loss: 0.3987 - val_accuracy: 0.8280
# Epoch 100/150
# 8/8 - 0s - loss: 0.3999 - accuracy: 0.8280 - val_loss: 0.4180 - val_accuracy: 0.8300
# Epoch 101/150
# 8/8 - 0s - loss: 0.3991 - accuracy: 0.8240 - val_loss: 0.4029 - val_accuracy: 0.8160
# Epoch 102/150
# 8/8 - 0s - loss: 0.3947 - accuracy: 0.8360 - val_loss: 0.3993 - val_accuracy: 0.8360
# Epoch 103/150
# 8/8 - 0s - loss: 0.4017 - accuracy: 0.8260 - val_loss: 0.4081 - val_accuracy: 0.8220
# Epoch 104/150
# 8/8 - 0s - loss: 0.4138 - accuracy: 0.8180 - val_loss: 0.4004 - val_accuracy: 0.8240
# Epoch 105/150
# 8/8 - 0s - loss: 0.4018 - accuracy: 0.8240 - val_loss: 0.4050 - val_accuracy: 0.8220
# Epoch 106/150
# 8/8 - 0s - loss: 0.4194 - accuracy: 0.8080 - val_loss: 0.4088 - val_accuracy: 0.8240
# Epoch 107/150
# 8/8 - 0s - loss: 0.4215 - accuracy: 0.8200 - val_loss: 0.4478 - val_accuracy: 0.8080
# Epoch 108/150
# 8/8 - 0s - loss: 0.4003 - accuracy: 0.8220 - val_loss: 0.4079 - val_accuracy: 0.8180
# Epoch 109/150
# 8/8 - 0s - loss: 0.4084 - accuracy: 0.8300 - val_loss: 0.4063 - val_accuracy: 0.8180
# Epoch 110/150
# 8/8 - 0s - loss: 0.3937 - accuracy: 0.8360 - val_loss: 0.4012 - val_accuracy: 0.8280
# Epoch 111/150
# 8/8 - 0s - loss: 0.3995 - accuracy: 0.8320 - val_loss: 0.4042 - val_accuracy: 0.8240
# Epoch 112/150
# 8/8 - 0s - loss: 0.4037 - accuracy: 0.8220 - val_loss: 0.4079 - val_accuracy: 0.8200
# Epoch 113/150
# 8/8 - 0s - loss: 0.3955 - accuracy: 0.8240 - val_loss: 0.4071 - val_accuracy: 0.8240
# Epoch 114/150
# 8/8 - 0s - loss: 0.3911 - accuracy: 0.8340 - val_loss: 0.4463 - val_accuracy: 0.8120
# Epoch 115/150
# 8/8 - 0s - loss: 0.3892 - accuracy: 0.8440 - val_loss: 0.4036 - val_accuracy: 0.8300
# Epoch 116/150
# 8/8 - 0s - loss: 0.3925 - accuracy: 0.8320 - val_loss: 0.4091 - val_accuracy: 0.8220
# Epoch 117/150
# 8/8 - 0s - loss: 0.3966 - accuracy: 0.8220 - val_loss: 0.4802 - val_accuracy: 0.7940
# Epoch 118/150
# 8/8 - 0s - loss: 0.4262 - accuracy: 0.8240 - val_loss: 0.4479 - val_accuracy: 0.8040
# Epoch 119/150
# 8/8 - 0s - loss: 0.4037 - accuracy: 0.8280 - val_loss: 0.4101 - val_accuracy: 0.8180
# Epoch 120/150
# 8/8 - 0s - loss: 0.4017 - accuracy: 0.8260 - val_loss: 0.4082 - val_accuracy: 0.8220
# Epoch 121/150
# 8/8 - 0s - loss: 0.3915 - accuracy: 0.8280 - val_loss: 0.4085 - val_accuracy: 0.8260
# Epoch 122/150
# 8/8 - 0s - loss: 0.3906 - accuracy: 0.8380 - val_loss: 0.4032 - val_accuracy: 0.8220
# Epoch 123/150
# 8/8 - 0s - loss: 0.3924 - accuracy: 0.8320 - val_loss: 0.4051 - val_accuracy: 0.8280
# Epoch 124/150
# 8/8 - 0s - loss: 0.3957 - accuracy: 0.8260 - val_loss: 0.4476 - val_accuracy: 0.8140
# Epoch 125/150
# 8/8 - 0s - loss: 0.4064 - accuracy: 0.8120 - val_loss: 0.4784 - val_accuracy: 0.7840
# Epoch 126/150
# 8/8 - 0s - loss: 0.4245 - accuracy: 0.8200 - val_loss: 0.4067 - val_accuracy: 0.8240
# Epoch 127/150
# 8/8 - 0s - loss: 0.4019 - accuracy: 0.8260 - val_loss: 0.4079 - val_accuracy: 0.8200
# Epoch 128/150
# 8/8 - 0s - loss: 0.3920 - accuracy: 0.8220 - val_loss: 0.4013 - val_accuracy: 0.8300
# Epoch 129/150
# 8/8 - 0s - loss: 0.3969 - accuracy: 0.8240 - val_loss: 0.4014 - val_accuracy: 0.8260
# Epoch 130/150
# 8/8 - 0s - loss: 0.4005 - accuracy: 0.8320 - val_loss: 0.4061 - val_accuracy: 0.8240
# Epoch 131/150
# 8/8 - 0s - loss: 0.4057 - accuracy: 0.8240 - val_loss: 0.4540 - val_accuracy: 0.8040
# Epoch 132/150
# 8/8 - 0s - loss: 0.4095 - accuracy: 0.8280 - val_loss: 0.4370 - val_accuracy: 0.8180
# Epoch 133/150
# 8/8 - 0s - loss: 0.3885 - accuracy: 0.8400 - val_loss: 0.4188 - val_accuracy: 0.8220
# Epoch 134/150
# 8/8 - 0s - loss: 0.3965 - accuracy: 0.8260 - val_loss: 0.4437 - val_accuracy: 0.8060
# Epoch 135/150
# 8/8 - 0s - loss: 0.4239 - accuracy: 0.8020 - val_loss: 0.4840 - val_accuracy: 0.7880
# Epoch 136/150
# 8/8 - 0s - loss: 0.4491 - accuracy: 0.8060 - val_loss: 0.4125 - val_accuracy: 0.8300
# Epoch 137/150
# 8/8 - 0s - loss: 0.3952 - accuracy: 0.8300 - val_loss: 0.4068 - val_accuracy: 0.8260
# Epoch 138/150
# 8/8 - 0s - loss: 0.4039 - accuracy: 0.8300 - val_loss: 0.4057 - val_accuracy: 0.8300
# Epoch 139/150
# 8/8 - 0s - loss: 0.3840 - accuracy: 0.8320 - val_loss: 0.4229 - val_accuracy: 0.8160
# Epoch 140/150
# 8/8 - 0s - loss: 0.3915 - accuracy: 0.8280 - val_loss: 0.4130 - val_accuracy: 0.8200
# Epoch 141/150
# 8/8 - 0s - loss: 0.3947 - accuracy: 0.8380 - val_loss: 0.4217 - val_accuracy: 0.8200
# Epoch 142/150
# 8/8 - 0s - loss: 0.3900 - accuracy: 0.8240 - val_loss: 0.4193 - val_accuracy: 0.8160
# Epoch 143/150
# 8/8 - 0s - loss: 0.3925 - accuracy: 0.8220 - val_loss: 0.4368 - val_accuracy: 0.8180
# Epoch 144/150
# 8/8 - 0s - loss: 0.4182 - accuracy: 0.8200 - val_loss: 0.4321 - val_accuracy: 0.8140
# Epoch 145/150
# 8/8 - 0s - loss: 0.4043 - accuracy: 0.8280 - val_loss: 0.4138 - val_accuracy: 0.8240
# Epoch 146/150
# 8/8 - 0s - loss: 0.4093 - accuracy: 0.8240 - val_loss: 0.4074 - val_accuracy: 0.8280
# Epoch 147/150
# 8/8 - 0s - loss: 0.4320 - accuracy: 0.8240 - val_loss: 0.4818 - val_accuracy: 0.8060
# Epoch 148/150
# 8/8 - 0s - loss: 0.3945 - accuracy: 0.8320 - val_loss: 0.4140 - val_accuracy: 0.8220
# Epoch 149/150
# 8/8 - 0s - loss: 0.3924 - accuracy: 0.8440 - val_loss: 0.4126 - val_accuracy: 0.8220
# Epoch 150/150
# 8/8 - 0s - loss: 0.3913 - accuracy: 0.8280 - val_loss: 0.4046 - val_accuracy: 0.8260
# accuracy =  0.828   validation loss =  0.405
